# %% [markdown]
#     o	Import the Libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#     o	Importing the dataset.

# %%
data=pd.read_csv("titanic_dataset.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'
# Out:
# ('PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked')

# %%
data.shape
# Out:
# (891, 12)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
#     o	Checking for Null Values.

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data["Age"].fillna(data["Age"].mean(),inplace=True)

# %%
data["Cabin"].fillna(data["Cabin"].mode()[0],inplace=True)

# %%
data["Embarked"].fillna(data["Embarked"].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\srikr\AppData\Local\Temp\ipykernel_18700\2578434383.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <AxesSubplot: >

# %% [markdown]
#     o	Data Visualization.

# %%
sns.scatterplot(x="Age",y="Survived",data=data)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Survived'>

# %%
sns.lineplot(x="Age",y="Survived",data=data,ci=None)
# Out:
# C:\Users\srikr\AppData\Local\Temp\ipykernel_18700\4148504169.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="Age",y="Survived",data=data,ci=None)
# <AxesSubplot: xlabel='Age', ylabel='Survived'>

# %%
sns.distplot(data["Survived"])
# Out:
# C:\Users\srikr\AppData\Local\Temp\ipykernel_18700\3693270962.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Survived"])
# <AxesSubplot: xlabel='Survived', ylabel='Density'>

# %%
sns.relplot(x="Survived",y="Age",data=data,hue="Pclass")

# %%
sns.barplot(data=data,x="Survived",y="Age",ci=None)
# Out:
# C:\Users\srikr\AppData\Local\Temp\ipykernel_18700\2618163780.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data,x="Survived",y="Age",ci=None)
# <AxesSubplot: xlabel='Survived', ylabel='Age'>

# %%
sns.barplot(data=data,x="Survived",y="Age",hue="Pclass")
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='Age'>

# %%
sns.countplot(x="Survived",data=data)
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='count'>

# %%
sns.jointplot(x="Survived",y="Age",data=data)

# %% [markdown]
#     o	Outlier Detection

# %%
sns.boxplot(x="Survived",y="Age",data=data)
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='Age'>

# %% [markdown]
#     o	Splitting Dependent and Independent variables

# %%
x= data[['PassengerId', 'Pclass', 'Sex', 'Age', 'SibSp','Parch', 'Fare', 'Embarked']]
y=data['Survived']
labels=data['Survived']

# %%
x.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1       3    male  22.0      1      0   7.2500        S
# 1            2       1  female  38.0      1      0  71.2833        C
# 2            3       3  female  26.0      0      0   7.9250        S
# 3            4       1  female  35.0      1      0  53.1000        S
# 4            5       3    male  35.0      0      0   8.0500        S

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %% [markdown]
#     o	Perform Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
x["Sex"]=le.fit_transform(x["Sex"])
# Out:
# C:\Users\srikr\AppData\Local\Temp\ipykernel_18700\566333558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Sex"]=le.fit_transform(x["Sex"])

# %%
x["Sex"]
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int32

# %%
x["Sex"].value_counts()
# Out:
# 1    577
# 0    314
# Name: Sex, dtype: int64

# %%
x["Sex"].nunique()
# Out:
# 2

# %%
x['Embarked']=le.fit_transform(x['Embarked'])
# Out:
# C:\Users\srikr\AppData\Local\Temp\ipykernel_18700\2142337331.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Embarked']=le.fit_transform(x['Embarked'])

# %%
x['Embarked']
# Out:
# 0      2
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 886    2
# 887    2
# 888    2
# 889    0
# 890    1
# Name: Embarked, Length: 891, dtype: int32

# %%
x["Embarked"].value_counts()
# Out:
# 2    646
# 0    168
# 1     77
# Name: Embarked, dtype: int64

# %%
x['Embarked'].nunique()
# Out:
# 3

# %% [markdown]
#     o	Splitting Data into Train and Test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((623, 8), (268, 8), (623,), (268,))

# %% [markdown]
#     o	Feature Scaling.

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[ 1.59014094, -1.5325562 ,  0.72592065, ..., -0.47299765,
#         -0.12253019,  0.56710989],
#        [-1.52952238, -1.5325562 , -1.37756104, ..., -0.47299765,
#          0.91812372, -2.03075381],
#        [-0.23515275,  0.84844757,  0.72592065, ...,  1.93253327,
#          0.29950338,  0.56710989],
#        ...,
#        [ 0.70655928,  0.84844757,  0.72592065, ..., -0.47299765,
#         -0.51276504, -0.73182196],
#        [ 0.43528421,  0.84844757, -1.37756104, ..., -0.47299765,
#         -0.31228976,  0.56710989],
#        [ 0.91970398, -0.34205431,  0.72592065, ...,  0.72976781,
#          0.13566725,  0.56710989]])

# %%
x_test
# Out:
# array([[ 0.21119888,  0.77963055,  0.76537495, ..., -0.47809977,
#         -0.324475  , -1.76531134],
#        [ 0.8106727 ,  0.77963055,  0.76537495, ..., -0.47809977,
#         -0.45513843,  0.63014911],
#        [-0.63903523,  0.77963055,  0.76537495, ...,  0.87064484,
#         -0.04706937, -0.56758111],
#        ...,
#        [ 0.70096507,  0.77963055,  0.76537495, ..., -0.47809977,
#         -0.32455255, -1.76531134],
#        [ 1.35137458,  0.77963055, -1.30654916, ..., -0.47809977,
#         -0.45616356,  0.63014911],
#        [-1.47751496, -1.64991582,  0.76537495, ..., -0.47809977,
#         -0.07362838, -1.76531134]])

# %%
y_train
# Out:
# 857    1
# 52     1
# 386    0
# 124    0
# 578    0
#       ..
# 835    1
# 192    1
# 629    0
# 559    1
# 684    0
# Name: Survived, Length: 623, dtype: int64

# %%
y_test
# Out:
# 495    0
# 648    0
# 278    0
# 31     1
# 255    1
#       ..
# 263    0
# 718    0
# 620    0
# 786    1
# 64     0
# Name: Survived, Length: 268, dtype: int64
